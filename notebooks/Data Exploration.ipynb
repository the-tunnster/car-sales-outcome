# %%
import numpy
import pandas
import altair
#import ydata_profiling

# %%
dataFrame = pandas.read_csv("/content/drive/MyDrive/MLAA/Assignment 2/Datasets/training.csv")
dataFrame.shape
# Out:
# (131337, 17)

# %%
dataFrame.head()
# Out:
#    ID  Target     age_band  gender car_model   car_segment  \
# 0   1       0  3. 35 to 44    Male   model_1           LCV
# 1   2       0          NaN     NaN   model_2  Small/Medium
# 2   3       0          NaN    Male   model_3     Large/SUV
# 3   5       0          NaN     NaN   model_3     Large/SUV
# 4   6       0          NaN  Female   model_2  Small/Medium
#
#    age_of_vehicle_years  sched_serv_warr  non_sched_serv_warr  \
# 0                     9                2                   10
# 1                     6               10                    3
# 2                     9               10                    9
# 3                     5                8                    5
# 4                     8                9                    4
#
#    sched_serv_paid  non_sched_serv_paid  total_paid_services  total_services  \
# 0                3                    7                    5               6
# 1               10                    4                    9              10
# 2               10                    9                   10              10
# 3                8                    4                    5               6
# 4               10                    7                    9               8
#
#    mth_since_last_serv  annualised_mileage  num_dealers_visited  \
# 0                    9                   8                   10
# 1                    6                  10                    7
# 2                    7                  10                    6
# 3                    4                  10                    9
# 4                    5                   4                    4
#
#    num_serv_dealer_purchased
# 0                          4
# 1                         10
# 2                         10
# 3                          7
# 4                          9

# %%
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131337 entries, 0 to 131336
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   ID                         131337 non-null  int64
#  1   Target                     131337 non-null  int64
#  2   age_band                   18962 non-null   object
#  3   gender                     62029 non-null   object
#  4   car_model                  131337 non-null  object
#  5   car_segment                131337 non-null  object
#  6   age_of_vehicle_years       131337 non-null  int64
#  7   sched_serv_warr            131337 non-null  int64
#  8   non_sched_serv_warr        131337 non-null  int64
#  9   sched_serv_paid            131337 non-null  int64
#  10  non_sched_serv_paid        131337 non-null  int64
#  11  total_paid_services        131337 non-null  int64
#  12  total_services             131337 non-null  int64
#  13  mth_since_last_serv        131337 non-null  int64
#  14  annualised_mileage         131337 non-null  int64
#  15  num_dealers_visited        131337 non-null  int64
#  16  num_serv_dealer_purchased  131337 non-null  int64
# dtypes: int64(13), object(4)
# memory usage: 17.0+ MB

# %%
dataFrame.describe()
# Out:
#                   ID         Target  age_of_vehicle_years  sched_serv_warr  \
# count  131337.000000  131337.000000         131337.000000    131337.000000
# mean    77097.384180       0.026809              5.493022         5.452500
# std     44501.636704       0.161525              2.843299         2.884328
# min         1.000000       0.000000              1.000000         1.000000
# 25%     38563.000000       0.000000              3.000000         3.000000
# 50%     77132.000000       0.000000              5.000000         5.000000
# 75%    115668.000000       0.000000              8.000000         8.000000
# max    154139.000000       1.000000             10.000000        10.000000
#
#        non_sched_serv_warr  sched_serv_paid  non_sched_serv_paid  \
# count        131337.000000    131337.000000        131337.000000
# mean              5.472517         5.452287             5.497050
# std               2.870665         2.886528             2.878699
# min               1.000000         1.000000             1.000000
# 25%               3.000000         3.000000             3.000000
# 50%               5.000000         5.000000             5.000000
# 75%               8.000000         8.000000             8.000000
# max              10.000000        10.000000            10.000000
#
#        total_paid_services  total_services  mth_since_last_serv  \
# count        131337.000000   131337.000000        131337.000000
# mean              5.481692        5.454967             5.469807
# std               2.880408        2.875961             2.859756
# min               1.000000        1.000000             1.000000
# 25%               3.000000        3.000000             3.000000
# 50%               5.000000        5.000000             5.000000
# 75%               8.000000        8.000000             8.000000
# max              10.000000       10.000000            10.000000
#
#        annualised_mileage  num_dealers_visited  num_serv_dealer_purchased
# count       131337.000000        131337.000000              131337.000000
# mean             5.502836             5.485438                   5.480778
# std              2.854896             2.876772                   2.867524
# min              1.000000             1.000000                   1.000000
# 25%              3.000000             3.000000                   3.000000
# 50%              5.000000             5.000000                   5.000000
# 75%              8.000000             8.000000                   8.000000
# max             10.000000            10.000000                  10.000000

# %%
genderDictionary = {"Male" : 1,
                    "Female" : 2,
                    numpy.nan : 3}

ageBandDictionary = {"1. <25" : 1,
                     "2. 25 to 34" : 2,
                     "3. 35 to 44" : 3,
                     "4. 45 to 54" : 4,
                     "5. 55 to 64" : 5,
                     "6. 65 to 74" : 6,
                     "7. 75+": 7,
                     numpy.nan : 0}

carSegmentDictionary = {"Small/Medium" : 1,
                        "Large/SUV" : 2,
                        "LCV" : 3,
                        "Other" : 4}

carModelDictionary = {"model_1" : 1,
                      "model_2" : 2,
                      "model_3" : 3,
                      "model_4" : 4,
                      "model_5" : 5,
                      "model_6" : 6,
                      "model_7" : 7,
                      "model_8" : 8,
                      "model_9" : 9,
                      "model_10" : 10,
                      "model_11" : 11,
                      "model_12" : 12,
                      "model_13" : 13,
                      "model_14" : 14,
                      "model_15" : 15,
                      "model_16" : 16,
                      "model_17" : 17,
                      "model_18" : 18,
                      "model_19" : 19}

# %%
dataFrame["gender"].replace(genderDictionary, inplace=True)
dataFrame["age_band"].replace(ageBandDictionary, inplace=True)
dataFrame["car_model"].replace(carModelDictionary, inplace=True)
dataFrame["car_segment"].replace(carSegmentDictionary, inplace=True)

# %%
dataFrame.head()
# Out:
#    ID  Target  age_band  gender  car_model  car_segment  age_of_vehicle_years  \
# 0   1       0       3.0     1.0          1            3                     9
# 1   2       0       0.0     3.0          2            1                     6
# 2   3       0       0.0     1.0          3            2                     9
# 3   5       0       0.0     3.0          3            2                     5
# 4   6       0       0.0     2.0          2            1                     8
#
#    sched_serv_warr  non_sched_serv_warr  sched_serv_paid  non_sched_serv_paid  \
# 0                2                   10                3                    7
# 1               10                    3               10                    4
# 2               10                    9               10                    9
# 3                8                    5                8                    4
# 4                9                    4               10                    7
#
#    total_paid_services  total_services  mth_since_last_serv  \
# 0                    5               6                    9
# 1                    9              10                    6
# 2                   10              10                    7
# 3                    5               6                    4
# 4                    9               8                    5
#
#    annualised_mileage  num_dealers_visited  num_serv_dealer_purchased
# 0                   8                   10                          4
# 1                  10                    7                         10
# 2                  10                    6                         10
# 3                  10                    9                          7
# 4                   4                    4                          9

# %%
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131337 entries, 0 to 131336
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   ID                         131337 non-null  int64
#  1   Target                     131337 non-null  int64
#  2   age_band                   131337 non-null  float64
#  3   gender                     131337 non-null  float64
#  4   car_model                  131337 non-null  int64
#  5   car_segment                131337 non-null  int64
#  6   age_of_vehicle_years       131337 non-null  int64
#  7   sched_serv_warr            131337 non-null  int64
#  8   non_sched_serv_warr        131337 non-null  int64
#  9   sched_serv_paid            131337 non-null  int64
#  10  non_sched_serv_paid        131337 non-null  int64
#  11  total_paid_services        131337 non-null  int64
#  12  total_services             131337 non-null  int64
#  13  mth_since_last_serv        131337 non-null  int64
#  14  annualised_mileage         131337 non-null  int64
#  15  num_dealers_visited        131337 non-null  int64
#  16  num_serv_dealer_purchased  131337 non-null  int64
# dtypes: float64(2), int64(15)
# memory usage: 17.0 MB

# %%
dataFrame.describe()
# Out:
#                   ID         Target       age_band         gender  \
# count  131337.000000  131337.000000  131337.000000  131337.000000
# mean    77097.384180       0.026809       0.553934       2.253059
# std     44501.636704       0.161525       1.476141       0.859261
# min         1.000000       0.000000       0.000000       1.000000
# 25%     38563.000000       0.000000       0.000000       1.000000
# 50%     77132.000000       0.000000       0.000000       3.000000
# 75%    115668.000000       0.000000       0.000000       3.000000
# max    154139.000000       1.000000       7.000000       3.000000
#
#            car_model    car_segment  age_of_vehicle_years  sched_serv_warr  \
# count  131337.000000  131337.000000         131337.000000    131337.000000
# mean        3.986120       1.772867              5.493022         5.452500
# std         2.595824       0.743571              2.843299         2.884328
# min         1.000000       1.000000              1.000000         1.000000
# 25%         2.000000       1.000000              3.000000         3.000000
# 50%         3.000000       2.000000              5.000000         5.000000
# 75%         5.000000       2.000000              8.000000         8.000000
# max        19.000000       4.000000             10.000000        10.000000
#
#        non_sched_serv_warr  sched_serv_paid  non_sched_serv_paid  \
# count        131337.000000    131337.000000        131337.000000
# mean              5.472517         5.452287             5.497050
# std               2.870665         2.886528             2.878699
# min               1.000000         1.000000             1.000000
# 25%               3.000000         3.000000             3.000000
# 50%               5.000000         5.000000             5.000000
# 75%               8.000000         8.000000             8.000000
# max              10.000000        10.000000            10.000000
#
#        total_paid_services  total_services  mth_since_last_serv  \
# count        131337.000000   131337.000000        131337.000000
# mean              5.481692        5.454967             5.469807
# std               2.880408        2.875961             2.859756
# min               1.000000        1.000000             1.000000
# 25%               3.000000        3.000000             3.000000
# 50%               5.000000        5.000000             5.000000
# 75%               8.000000        8.000000             8.000000
# max              10.000000       10.000000            10.000000
#
#        annualised_mileage  num_dealers_visited  num_serv_dealer_purchased
# count       131337.000000        131337.000000              131337.000000
# mean             5.502836             5.485438                   5.480778
# std              2.854896             2.876772                   2.867524
# min              1.000000             1.000000                   1.000000
# 25%              3.000000             3.000000                   3.000000
# 50%              5.000000             5.000000                   5.000000
# 75%              8.000000             8.000000                   8.000000
# max             10.000000            10.000000                  10.000000

# %%
ydata_profiling.ProfileReport(dataFrame)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
